# %% [markdown]
# <a href="https://colab.research.google.com/github/h-wi/2022F-Ajou-ML/blob/main/HW1_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HW1 :: Data preprocessing & KNN

# %% [markdown]
# ## 코랩과 구글 드라이브 연동하기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# pwd 명령어로 현재 위치 확인
# !pwd
# Out:
# /content

# %%
# !ls
# Out:
# drive  sample_data

# %%
# 이 노트북 파일이 저장되어 있는 디렉토리 위치까지 옮기기
cd drive
# Out:
#   File "<ipython-input-6-c7fb00e33bce>", line 2
#     cd drive
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# ---

# %% [markdown]
# ## 데이터 불러오기 & 살펴보기

# %%
# 이번 과제는 numpy, pandas와 같은 데이터를 불러내고 확인, 처리, 
# 수정 등을 쉽게 할 수 있는 library를 사용합니다.

# 모듈 이름 뒤에 as를 쓰고 별칭을 적으면 해당 별칭으로 모듈을 호출할 수 있습니다.
# 모듈명: numpy, 별칭: np => numpy를 쓰는 대신 np를 써서 numpy 호출
# 모듈명: pandas, 별칭: pd => pandas를 쓰는 대신 pd를 써서 pandas 호출
import numpy as np
import pandas as pd

# %%
# './'는 이 노트북 파일의 현재 위치를 뜻 합니다.
# 노트북 파일과 같은 위치에 데이터 파일을 두어야 아래와 같이 데이터 파일을 불러올 수 있습니다.
# kaggle 원본 데이터 파일과 다릅니다. 반드시 제공된 데이터를 사용하세요!
path = './airline_sampled.csv' 

# pandas의 read_csv 함수를 사용하여 csv파일을 DataFrame으로 불러옵니다.
data = pd.read_csv(path)

# %%
# DataFrame 혹은 Series와 같은 자료구조에 shape함수를 통해 데이터의 크기와 
# 변수의 갯수를 대략적으로 알 수 있습니다.

data.shape # (10000, 23) => 10000 개의 row(행), 23 개의 column(열)을 가진 데이터
# Out:
# (10000, 23)

# %%
# head() 함수를 이용하여 해당 데이터의 맨 위 5개의 원소를 볼 수 있습니다.
# 더 많은 행을 보고 싶다면 ()안에 숫자를 넣어주시면 됩니다.

data.head(30)
# Out:
#     Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0        0              0   41               1      1              569
# 1        0              0   45               1      0             1085
# 2        0              0   23               1      1              468
# 3        0              0   34               1      2              303
# 4        1              0   21               1      1             1190
# 5        1              0   61               0      0             3883
# 6        0              0   59               1      1              293
# 7        0              0   57               0      0             3893
# 8        1              0   42               0      0              547
# 9        0              0   23               0      0              438
# 10       1              0   43               0      0              265
# 11       1              1   14               0      1              926
# 12       1              0   43               0      0              624
# 13       1              0   56               0      0             2946
# 14       1              1   21               0      1              130
# 15       1              0   56               0      0             1865
# 16       1              0   56               0      2             1106
# 17       0              0   50               0      0             2582
# 18       1              0   21               0      2             2133
# 19       0              0   40               1      1             1911
# 20       1              0   35               0      0             2489
# 21       0              0   40               0      1              156
# 22       0              0   40               1      1              399
# 23       1              0   29               0      0             2283
# 24       0              0   22               1      1              591
# 25       1              0   57               0      1              528
# 26       1              0   51               0      0              150
# 27       1              0   56               0      0              319
# 28       1              0   23               0      0              644
# 29       1              0   57               0      0               89
#
#     Inflight wifi service  Departure/Arrival time convenient  \
# 0                       2                                  5
# 1                       3                                  5
# 2                       3                                  2
# 3                       4                                  5
# 4                       4                                  4
# 5                       2                                  4
# 6                       4                                  5
# 7                       5                                  5
# 8                       4                                  4
# 9                       4                                  4
# 10                      0                                  0
# 11                      3                                  4
# 12                      2                                  5
# 13                      4                                  1
# 14                      2                                  4
# 15                      5                                  5
# 16                      3                                  3
# 17                      5                                  5
# 18                      1                                  1
# 19                      3                                  5
# 20                      2                                  4
# 21                      1                                  4
# 22                      3                                  4
# 23                      3                                  4
# 24                      1                                  4
# 25                      5                                  3
# 26                      1                                  1
# 27                      4                                  4
# 28                      3                                  3
# 29                      2                                  2
#
#     Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                        2              4  ...                       2
# 1                        2              3  ...                       4
# 2                        3              2  ...                       5
# 3                        4              2  ...                       3
# 4                        4              4  ...                       1
# 5                        4              4  ...                       2
# 6                        4              1  ...                       1
# 7                        5              5  ...                       4
# 8                        4              4  ...                       3
# 9                        4              4  ...                       4
# 10                       0              5  ...                       5
# 11                       4              3  ...                       2
# 12                       5              5  ...                       2
# 13                       1              1  ...                       4
# 14                       2              4  ...                       3
# 15                       5              5  ...                       5
# 16                       3              3  ...                       3
# 17                       5              5  ...                       4
# 18                       1              1  ...                       1
# 19                       4              1  ...                       5
# 20                       2              2  ...                       4
# 21                       4              4  ...                       1
# 22                       3              1  ...                       1
# 23                       4              4  ...                       3
# 24                       1              4  ...                       2
# 25                       3              3  ...                       4
# 26                       1              1  ...                       5
# 27                       4              4  ...                       5
# 28                       3              3  ...                       3
# 29                       2              2  ...                       5
#
#     On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                  1                 5                 3                3
# 1                  4                 2                 4                4
# 2                  1                 4                 2                1
# 3                  5                 5                 5                3
# 4                  5                 3                 3                3
# 5                  2                 2                 2                2
# 6                  1                 4                 4                3
# 7                  4                 4                 4                5
# 8                  3                 3                 3                4
# 9                  1                 2                 2                5
# 10                 5                 3                 3                4
# 11                 2                 4                 4                1
# 12                 2                 2                 2                3
# 13                 4                 4                 4                1
# 14                 3                 4                 5                5
# 15                 5                 5                 5                5
# 16                 3                 1                 3                3
# 17                 4                 4                 4                3
# 18                 3                 3                 4                3
# 19                 5                 2                 3                5
# 20                 4                 4                 4                5
# 21                 2                 4                 3                3
# 22                 5                 1                 2                5
# 23                 3                 1                 1                4
# 24                 4                 4                 5                4
# 25                 2                 2                 3                4
# 26                 5                 5                 4                4
# 27                 5                 5                 5                3
# 28                 2                 3                 3                1
# 29                 5                 5                 4                3
#
#     Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                  1            2                           0
# 1                  4            3                          23
# 2                  3            5                           4
# 3                  5            3                          49
# 4                  4            1                           8
# 5                  2            2                           0
# 6                  1            5                          42
# 7                  4            5                          58
# 8                  3            4                           0
# 9                  3            4                           0
# 10                 5            3                          11
# 11                 3            2                           2
# 12                 2            2                          12
# 13                 4            1                          76
# 14                 5            3                          15
# 15                 5            3                          16
# 16                 3            3                           0
# 17                 4            3                           6
# 18                 4            1                           0
# 19                 5            5                           6
# 20                 4            5                           0
# 21                 2            1                          95
# 22                 1            1                           0
# 23                 2            3                          44
# 24                 4            2                           1
# 25                 3            4                          53
# 26                 5            3                           0
# 27                 5            1                           0
# 28                 4            3                          39
# 29                 5            4                           5
#
#     Arrival Delay in Minutes  satisfaction
# 0                        0.0             0
# 1                        0.0             0
# 2                        0.0             0
# 3                       50.0             0
# 4                        0.0             1
# 5                       13.0             0
# 6                       26.0             0
# 7                       64.0             1
# 8                        0.0             1
# 9                       12.0             1
# 10                       0.0             1
# 11                       0.0             0
# 12                      38.0             0
# 13                      66.0             0
# 14                      18.0             0
# 15                      10.0             1
# 16                      14.0             0
# 17                       2.0             1
# 18                       0.0             0
# 19                      21.0             0
# 20                       0.0             1
# 21                      89.0             0
# 22                       0.0             0
# 23                      37.0             0
# 24                       0.0             0
# 25                      52.0             1
# 26                       0.0             1
# 27                       0.0             1
# 28                      22.0             0
# 29                       4.0             1
#
# [30 rows x 23 columns]

# %%
# tail() 함수를 이용하여 해당 데이터의 맨 뒤 5개의 원소를 볼 수 있습니다.
# 더 많은 행을 보고 싶다면 ()안에 숫자를 넣어주시면 됩니다.

data.tail()
# Out:
#       Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 9995       1              0   53               0      1              834
# 9996       1              0   42               0      1              134
# 9997       1              0   64               1      2              425
# 9998       1              0   46               0      0             2374
# 9999       1              0   59               0      0             2637
#
#       Inflight wifi service  Departure/Arrival time convenient  \
# 9995                      1                                  4
# 9996                      2                                  2
# 9997                      2                                  2
# 9998                      3                                  3
# 9999                      4                                  4
#
#       Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 9995                       4              4  ...                       1
# 9996                       2              2  ...                       2
# 9997                       2              2  ...                       2
# 9998                       3              3  ...                       3
# 9999                       4              4  ...                       3
#
#       On-board service  Leg room service  Baggage handling  Checkin service  \
# 9995                 1                 1                 3                4
# 9996                 3                 4                 3                2
# 9997                 3                 2                 2                1
# 9998                 3                 4                 3                5
# 9999                 3                 4                 3                4
#
#       Inflight service  Cleanliness  Departure Delay in Hours  \
# 9995                 4            1                        28
# 9996                 1            2                       143
# 9997                 3            2                         9
# 9998                 3            5                         0
# 9999                 3            4                        16
#
#       Arrival Delay in Hours  satisfaction
# 9995                0.133333             0
# 9996                2.650000             0
# 9997                1.400000             0
# 9998                0.000000             1
# 9999                0.016667             1
#
# [5 rows x 23 columns]

# %%
# DataFrame을 이루고 있는 column의 이름을 확인합니다.

data.columns
# Out:
# Index(['Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
# DataFrame을 이루고 있는 column 별 데이터의 타입을 확인합니다.

data.dtypes
# Out:
# Gender                                object
# Customer Type                         object
# Age                                    int64
# Type of Travel                        object
# Class                                 object
# Flight Distance                        int64
# Inflight wifi service                  int64
# Departure/Arrival time convenient      int64
# Ease of Online booking                 int64
# Gate location                          int64
# Food and drink                         int64
# Online boarding                        int64
# Seat comfort                           int64
# Inflight entertainment                 int64
# On-board service                       int64
# Leg room service                       int64
# Baggage handling                       int64
# Checkin service                        int64
# Inflight service                       int64
# Cleanliness                            int64
# Departure Delay in Minutes             int64
# Arrival Delay in Minutes             float64
# satisfaction                          object
# dtype: object

# %%
# describe()는 각 column에 대해 통계량을 요약해주는 함수입니다.
# 기본적으로 NaN(누락데이터)는 제외하고 데이터 요약이 수행됩니다.

data.describe()
# Out:
#              Gender  Customer Type           Age  Type of Travel        Class  \
# count  10000.000000   10000.000000  10000.000000    10000.000000  10000.00000
# mean       0.494900       0.176600     39.528600        0.309700      0.59130
# std        0.499999       0.381349     15.091122        0.462393      0.61976
# min        0.000000       0.000000      7.000000        0.000000      0.00000
# 25%        0.000000       0.000000     27.000000        0.000000      0.00000
# 50%        0.000000       0.000000     40.000000        0.000000      1.00000
# 75%        1.000000       0.000000     51.000000        1.000000      1.00000
# max        1.000000       1.000000     85.000000        1.000000      2.00000
#
#        Flight Distance  Inflight wifi service  \
# count     10000.000000           10000.000000
# mean       1199.730400               2.747700
# std        1014.036332               1.320234
# min          31.000000               0.000000
# 25%         407.000000               2.000000
# 50%         842.000000               3.000000
# 75%        1749.000000               4.000000
# max        4983.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                       10000.000000            10000.000000
# mean                            3.062200                2.767800
# std                             1.511277                1.398027
# min                             0.000000                0.000000
# 25%                             2.000000                2.000000
# 50%                             3.000000                3.000000
# 75%                             4.000000                4.000000
# max                             5.000000                5.000000
#
#        Gate location  ...  Inflight entertainment  On-board service  \
# count   10000.000000  ...            10000.000000      10000.000000
# mean        2.984700  ...                3.360000          3.380600
# std         1.278683  ...                1.332208          1.293024
# min         0.000000  ...                1.000000          1.000000
# 25%         2.000000  ...                2.000000          2.000000
# 50%         3.000000  ...                4.000000          4.000000
# 75%         4.000000  ...                4.000000          4.000000
# max         5.000000  ...                5.000000          5.000000
#
#        Leg room service  Baggage handling  Checkin service  Inflight service  \
# count      10000.000000      10000.000000     10000.000000      10000.000000
# mean           3.363200          3.634600         3.296500          3.633600
# std            1.318507          1.190388         1.259661          1.185028
# min            0.000000          1.000000         1.000000          1.000000
# 25%            2.000000          3.000000         2.000000          3.000000
# 50%            4.000000          4.000000         3.000000          4.000000
# 75%            4.000000          5.000000         4.000000          5.000000
# max            5.000000          5.000000         5.000000          5.000000
#
#         Cleanliness  Departure Delay in Hours  Arrival Delay in Hours  \
# count  10000.000000              10000.000000             9965.000000
# mean       3.286000                  0.243503                0.252268
# std        1.297294                  0.611412                0.619998
# min        1.000000                  0.000000                0.000000
# 25%        2.000000                  0.000000                0.000000
# 50%        3.000000                  0.000000                0.000000
# 75%        4.000000                  0.216667                0.233333
# max        5.000000                 12.466667               12.000000
#
#        satisfaction
# count  10000.000000
# mean       0.440000
# std        0.496412
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
#
# [8 rows x 23 columns]

# %% [markdown]
# ## 문제 1 :: 변수의 타입

# %% [markdown]
# * 보고서에 설명된 것을 바탕을 주어진 데이터의 변수들의 타입을 보고서에 기술하세요.
#
#   * 작성 형식) : 1. 변수 이름: categorical
#   * 작성 예시) 1. Age: Numeric

# %% [markdown]
# 정답)
# * Gender: categorical
# * Customer type: categorical
# * Age: Numeric
# * Type of travel: categorical
# * Class: categorical
# * Flight Distance: Numeric
# * Inflight wifi service: Numeric
# * Departure/Arrival time convenient: Numeric
# * Ease of Online booking: Numeric
# * Gate location: Numeric
# * Food and drink: Numeric
# * Online boarding: Numeric
# * Seat comfort: Numeric
# * Inflight entertainment: Numeric
# * On-board service: Numeric
# * Leg room service: Numeric
# * Baggage handling: Numeric
# * Checkin service: Numeric
# * Inflight service: Numeric
# * Cleanliness: Numeric
# * Departure Delay in Minutes: Numeric
# * Arrival Delay in Minutes: Numeric
# * satisfaction: categorical

# %% [markdown]
# ## 결측값과 중복값 확인하기
# 결측값과 중복값은 데이터 분석 결과에 큰 영향을 줍니다.
# 제공된 데이터에 결측값과 중복값이 있는지 알아봅시다.

# %%
# isnull()는 DataFrame에 있는 결측치(NA)를 boolean 값으로 반환하는 함수입니다.
# 결측치가 있으면 True를 반환합니다.

data.isnull().head()
# Out:
#    Gender  Customer Type    Age  Type of Travel  Class  Flight Distance  \
# 0   False          False  False           False  False            False
# 1   False          False  False           False  False            False
# 2   False          False  False           False  False            False
# 3   False          False  False           False  False            False
# 4   False          False  False           False  False            False
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                  False                              False
# 1                  False                              False
# 2                  False                              False
# 3                  False                              False
# 4                  False                              False
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                   False          False  ...                   False
# 1                   False          False  ...                   False
# 2                   False          False  ...                   False
# 3                   False          False  ...                   False
# 4                   False          False  ...                   False
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0             False             False             False            False
# 1             False             False             False            False
# 2             False             False             False            False
# 3             False             False             False            False
# 4             False             False             False            False
#
#    Inflight service  Cleanliness  Departure Delay in Hours  \
# 0             False        False                     False
# 1             False        False                     False
# 2             False        False                     False
# 3             False        False                     False
# 4             False        False                     False
#
#    Arrival Delay in Hours  satisfaction
# 0                   False         False
# 1                   False         False
# 2                   False         False
# 3                   False         False
# 4                   False         False
#
# [5 rows x 23 columns]

# %%
# isnull()에 sum() 를 결합하여 DataFrame에 있는 결측치의 합을 구합니다.

data.isnull().sum() # 문제3에서 KNN Imputer를 사용하여 결측값을 보정할 예정
# Out:
# Gender                                0
# Customer Type                         0
# Age                                   0
# Type of Travel                        0
# Class                                 0
# Flight Distance                       0
# Inflight wifi service                 0
# Departure/Arrival time convenient     0
# Ease of Online booking                0
# Gate location                         0
# Food and drink                        0
# Online boarding                       0
# Seat comfort                          0
# Inflight entertainment                0
# On-board service                      0
# Leg room service                      0
# Baggage handling                      0
# Checkin service                       0
# Inflight service                      0
# Cleanliness                           0
# Departure Delay in Hours              0
# Arrival Delay in Hours               35
# satisfaction                          0
# dtype: int64

# %%
# duplicated()는 중복된 데이터를 Series 형식으로 반환합니다.

data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
# duplicated()에 sum()을 결합하여 DataFrame에 있는 중복 데이터의 합을 구합니다.

data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 문제 2 :: 데이터 정리

# %% [markdown]
# ### 문제 2-1
# 제공된 데이터에서 categorical 변수들을 주어진 조건에 따라 인코딩하고 작성한 코드를 캡처 후 보고서에 업로드 하세요.
#
# * data에서 satisfaction 열의 데이터 값을 `neutral or dissatisfied` 일 경우 0, `satisfied`일 경우 1로 인코딩하세요.
#
# * data에서 Gender 열의 데이터 값을 `Male`일 경우 0, `Female`일 경우 1로 인코딩하세요.
#
# * data에서 Customer Type 열의 데이터 값을 `disloyal Customer`일 경우 0, `Loyal Customer`일 경우 1로 인코딩하세요.
#
# * data에서 Class 열의 데이터 값을 `Eco`일 경우 0, `Eco Plus`일 경우 1, `Business`일 경우 2로 인코딩하세요.
#
# * data에서 'Type of Travel 열의 데이터 값을 `Personal Travel`일 경우 0, `Business travel`일 경우 1로 인코딩하세요.

# %%
data['Type of Travel'].unique()
# Out:
# array([1, 0])

# %%
data['Customer Type'].unique()
# Out:
# array([0, 1])

# %%
data['satisfaction'].unique() # satisfaction 열은 두 가지의 클래스로 구성되어 있다는 것을 확인합니다.
# Out:
# array([0, 1])

# %%
data['Class'].unique()
# Out:
# array([1, 0, 2])

# %%
################  문제 2-1  ####################
# 소스코드를 입력하고 캡처 후 보고서에 업로드하세요.
# 코드 시작과 코드 끝 라인을 삭제하지 마세요.
################ 코드 시작  #####################
from sklearn.preprocessing import LabelEncoder
categoric = ['Type of Travel','Customer Type','satisfaction','Class','Gender']
for i in categoric:
  encoder = LabelEncoder()
  encoder.fit(data[i])
  data[i] = encoder.transform(data[i])
##################################################

# %%
data.shape
# Out:
# (10000, 23)

# %%
# 인코딩한 데이터 열의 데이터 속성을 변환하는 코드
data['satisfaction'] = data['satisfaction'].astype('int')
data['Gender'] = data['Gender'].astype('int')
data['Customer Type'] = data['Customer Type'].astype('int')
data['Class'] = data['Class'].astype('int')
data['Type of Travel'] = data['Type of Travel'].astype('int')

# %% [markdown]
# ### 문제 2-2
# `Arrival Delay in Minutes` 열은 현재 분 단위로 데이터가 구성되어 있습니다.
# 시간 단위로 데이터를 나타내는 `delay_in_hours`을 작성하고 캡처하여 보고서에 업로드 하세요.
#
#
# 예) 18분 => 18/60=0.3

# %%
################  문제 2-2  ####################
# 소스코드를 입력하고 캡처 후 보고서에 업로드하세요.
# 코드 시작과 코드 끝 라인을 삭제하지 마세요.
################ 코드 시작  #####################
def delay_in_hours(row):
  return row/60
################ 코드 끝 ########################
#################################################

# %%
data['Arrival Delay in Minutes'] = data['Arrival Delay in Minutes'].apply(lambda row: delay_in_hours(row))

# %%
data # Arrival Delay in Minutes 열이 바뀌었는지 확인
# Out:
#       Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0          0              0   41               1      1              569
# 1          0              0   45               1      0             1085
# 2          0              0   23               1      1              468
# 3          0              0   34               1      2              303
# 4          1              0   21               1      1             1190
# ...      ...            ...  ...             ...    ...              ...
# 9995       1              0   53               0      1              834
# 9996       1              0   42               0      1              134
# 9997       1              0   64               1      2              425
# 9998       1              0   46               0      0             2374
# 9999       1              0   59               0      0             2637
#
#       Inflight wifi service  Departure/Arrival time convenient  \
# 0                         2                                  5
# 1                         3                                  5
# 2                         3                                  2
# 3                         4                                  5
# 4                         4                                  4
# ...                     ...                                ...
# 9995                      1                                  4
# 9996                      2                                  2
# 9997                      2                                  2
# 9998                      3                                  3
# 9999                      4                                  4
#
#       Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                          2              4  ...                       2
# 1                          2              3  ...                       4
# 2                          3              2  ...                       5
# 3                          4              2  ...                       3
# 4                          4              4  ...                       1
# ...                      ...            ...  ...                     ...
# 9995                       4              4  ...                       1
# 9996                       2              2  ...                       2
# 9997                       2              2  ...                       2
# 9998                       3              3  ...                       3
# 9999                       4              4  ...                       3
#
#       On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                    1                 5                 3                3
# 1                    4                 2                 4                4
# 2                    1                 4                 2                1
# 3                    5                 5                 5                3
# 4                    5                 3                 3                3
# ...                ...               ...               ...              ...
# 9995                 1                 1                 3                4
# 9996                 3                 4                 3                2
# 9997                 3                 2                 2                1
# 9998                 3                 4                 3                5
# 9999                 3                 4                 3                4
#
#       Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                    1            2                           0
# 1                    4            3                          23
# 2                    3            5                           4
# 3                    5            3                          49
# 4                    4            1                           8
# ...                ...          ...                         ...
# 9995                 4            1                          28
# 9996                 1            2                         143
# 9997                 3            2                           9
# 9998                 3            5                           0
# 9999                 3            4                          16
#
#       Arrival Delay in Minutes  satisfaction
# 0                     0.000000             0
# 1                     0.000000             0
# 2                     0.000000             0
# 3                     0.833333             0
# 4                     0.000000             1
# ...                        ...           ...
# 9995                  0.133333             0
# 9996                  2.650000             0
# 9997                  1.400000             0
# 9998                  0.000000             1
# 9999                  0.016667             1
#
# [10000 rows x 23 columns]

# %%
data['Departure Delay in Minutes'] = data['Departure Delay in Minutes'].apply(lambda row: delay_in_hours(row))

# %% [markdown]
# ### 문제 2-3
# `Departure Delay in Minutes`와 `Arrival Delay in Minutes` 열의 이름을 각각 `Departure Delay in Hours`와 `Arrival Delay in Hours`로 변경하세요.
#
# **코드를 보고서에 캡처하여 업로드하세요.**

# %%
################  문제 2-3  #################
# 열 이름 변경하기
# 소스코드를 입력하고 캡처 후 보고서에 업로드하세요.
# 코드 시작과 코드 끝 라인을 삭제하지 마세요.
################ 코드 시작  ##################
data.rename(columns={'Departure Delay in Minutes' : 'Departure Delay in Hours'}, inplace = True)
data.rename(columns={'Arrival Delay in Minutes' : 'Arrival Delay in Hours'}, inplace = True)
################ 코드 끝  ####################
##############################################

# %%
data.rename(columns={'Departure Delay in Hours' : 'Departure Delay in Minutes'}, inplace = True)

# %% [markdown]
# ## 문제 3 :: KNN Imputer

# %% [markdown]
# ### **`Arrival Delay in Hours`** 열과 연관성이 높은 열 찾기

# %% [markdown]
# 결측값이 있는 모든 행과 결측값이 없는 데이터 사이의 거리를 구할 수 있지만, 계산 시간이 매우 오려 걸려 `Arrival Delay in Hours` 열과 가장 연관성이 높은 `Departure Delay in Hours` 과의 거리를 기준으로 결측값을 보정합니다.

# %%
corr = data.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T
{
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_785ac_row2_col6, #T_785ac_row3_col5, #T_785ac_row3_col16, #T_785ac_row8_col10, #T_785ac_row12_col1, #T_785ac_row17_col8, #T_785ac_row20_col8 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_785ac_row2_col7, #T_785ac_row3_col2, #T_785ac_row8_col18, #T_785ac_row9_col12, #T_785ac_row10_col18 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_785ac_row2_col11 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_785ac_row2_col12, #T_785ac_row11_col14, #T_785ac_row20_col4 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_785ac_row2_col14, #T_785ac_row8_col1, #T_785ac_row9_col2, #T_785ac_row14_col7, #T_785ac_row19_col18 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_785ac_row2_col19, #T_785ac_row13_col8, #T_785ac_row20_col14 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_785ac_row2_col20, #T_785ac_row3_col0, #T_785ac_row5_col9, #T_785ac_row6_col21, #T_785ac_row7_col21, #T_785ac_row8_col20, #T_785ac_row9_col0, #T_785ac_row19_col9, #T_785ac_row20_col0, #T_785ac_row21_col10 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_785ac_row2_col22, #T_785ac_row10_col11 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_785ac_row3_col4, #T_785ac_row4_col3, #T_785ac_row10_col12, #T_785ac_row13_col10 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_785ac_r

# %% [markdown]
# `Departure Delay in Hours` 와 `Arrival Delay in Hours`의 상관 계수가 0.96인 것으로 보아 두 열이 큰 상관 관계를 가짐을 알 수 있습니다.   따라서 두 열만 골라 X라는 데이터프레임을 만듭니다.

# %%
X = data[['Departure Delay in Hours', 'Arrival Delay in Hours']]

# %%
X
# Out:
#       Departure Delay in Hours  Arrival Delay in Hours
# 0                     0.000000                0.000000
# 1                     0.383333                0.000000
# 2                     0.066667                0.000000
# 3                     0.816667                0.833333
# 4                     0.133333                0.000000
# ...                        ...                     ...
# 9995                  0.466667                0.133333
# 9996                  2.383333                2.650000
# 9997                  0.150000                1.400000
# 9998                  0.000000                0.000000
# 9999                  0.266667                0.016667
#
# [10000 rows x 2 columns]

# %% [markdown]
# ### 문제 3-1, 3-2
# K-Nearest Neighbor Imputation(강의노트 24쪽)을 이용하여 결측치 채우기

# %% [markdown]
# ### 문제 3-1
# 주어진 코드틀에 데이터프레임 X와 결측값이 있는 행 데이터 간의 거리 구하는 코드를 작성하세요.
# * 주의) 코드틀 이외의 부분에 코드를 작성하지 마세요!
# * 주의) 소스코드를 입력하고 캡처 후 보고서에 업로드하세요.
# * 주의) 코드 시작과 코드 끝 라인을 삭제하지 마세요.

# %% [markdown]
# ### 문제 3-2
# 주어진 코드틀에 k개의 "Arrival Delay in Hours" 값을 보고 평균을 내어 결측값을 결정하는 코드를 작성하세요.
# * 주의) 코드틀 이외의 부분에 코드를 작성하지 마세요!
# * 주의) 소스코드를 입력하고 캡처 후 보고서에 업로드하세요.
# * 주의) 코드 시작과 코드 끝 라인을 삭제하지 마세요.

# %%
import tqdm

# %%
class Knn_imputer():
  def __init__(self, n_neighbors): 
        
    ## 생성자로 최근접 이웃수(n_neighbors)를 입력 받습니다.
    self.k = n_neighbors    
  
  ## knn 은 lazy learning 입니다.
  def fit(self,X):
      self.X = X
  
  def predict(self, X):

    for i in tqdm.tqdm(range(len(X))):
     if pd.isnull(X['Arrival Delay in Hours'].iloc[i]): # Arrival Delay 열에 있는 결측값 확인

        distance = self.dist(X, X.iloc[i]) # 데이터프레임 X와 결측값이 있는 행 데이터 간의 거리 구하는 함수
      
        
        sorted_dist = sorted(distance.items(), key=lambda x: x[1]) # distance 를 sorting 하기

         ################  문제 3-2  ####################
         # k개의 "Arrival Delay in Hours" 값을 보고 평균 내어
         # 값을 결정하기
         
         # 소스코드를 입력하고 캡처 후 보고서에 업로드하세요.
         # 코드 시작과 코드 끝 라인을 삭제하지 마세요.
        ################ 코드 시작  #####################


        
        ################ 코드 끝  ######################
        ##############################################
        
  
  def dist(self, X, y):
    num_train = X.shape[0]

    X = X.drop(['Arrival Delay in Hours'], axis=1)
    y = y.drop(['Arrival Delay in Hours'])
    dist_dict = {} ## {index : distance} 형태
    
    for i in range(num_train):
    
    ################  문제 3-1  ####################
    # 데이터프레임 X와 결측값이 있는 행 데이터 간의 거리 구하기
    # 소스코드를 입력하고 캡처 후 보고서에 업로드하세요.
    # 코드 시작과 코드 끝 라인을 삭제하지 마세요.
    ################ 코드 시작  #####################

     
    ################ 코드 끝  ######################
    ##############################################

    return dist_dict
# Out:
#   File "<ipython-input-55-daabb7d364cc>", line 57
#     return dist_dict
#          ^
# IndentationError: expected an indented block

# %%
imputer = Knn_imputer(3)
imputer.fit(X)

# test set에 대해 predict를 진행합니다.
imputer.predict(X) # 오래 걸립니다

# %%
X.isnull().sum() # 결측값이 채워졌는지 확인

# %% [markdown]
# ## 문제 4
# * satisfaction 열과의 상관 계수가 0.4 이상인 열만 추출하여 dataframe 생성 `data_final`을 생성하고 보고서에 어떤 열을 선택했는지 열의 이름을 서술하세요.
#
# * 선택한 열: Online boarding , Type of Travel, Class

# %%
corr = data.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_6d153_row0_col0, #T_6d153_row1_col1, #T_6d153_row2_col2, #T_6d153_row3_col3, #T_6d153_row4_col4, #T_6d153_row5_col5, #T_6d153_row6_col6, #T_6d153_row7_col7, #T_6d153_row8_col8, #T_6d153_row9_col9, #T_6d153_row10_col10, #T_6d153_row11_col11, #T_6d153_row12_col12, #T_6d153_row13_col13, #T_6d153_row14_col14, #T_6d153_row15_col15, #T_6d153_row16_col16, #T_6d153_row17_col17, #T_6d153_row18_col18, #T_6d153_row19_col19, #T_6d153_row20_col20, #T_6d153_row21_col21, #T_6d153_row22_col22 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_6d153_row0_col1, #T_6d153_row2_col15, #T_6d153_row5_col18, #T_6d153_row8_col12, #T_6d153_row12_col18, #T_6d153_row13_col3, #T_6d153_row16_col19, #T_6d153_row18_col4 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_6d153_row0_col2, #T_6d153_row8_col3, #T_6d153_row11_col16, #T_6d153_row13_col17, #T_6d153_row15_col8, #T_6d153_row16_col7, #T_6d153_row18_col7, #T_6d153_row19_col6 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_6d153_row0_col3, #T_6d153_row6_col15 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_6d153_row0_col4, #T_6d153_row5_col14, #T_6d153_row11_col10, #T_6d153_row16_col11, #T_6d153_row18_col3 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_6d153_row0_col5, #T_6d153_row6_col5, #T_6d153_row20_col5, #T_6d153_row21_col5 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_6d153_row0_col6, #T_6d153_row0_col19, #T_6d153_row1_col3, #T_6d153_row1_col17, #T_6d153_row2_col10, #T_6d153_row5_col6, #T_6d153_row9_col19, #T_6d153_row21_col8 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T
# 2                  3               1      1             0
# 3                  4               1      2             0
# 4                  4               1      1             1
# ..               ...             ...    ...           ...
# 495                4               1      1             0
# 496                5               0      0             1
# 497                1               0      1             0
# 498                3               1      1             0
# 499                5               0      0             1
#
# [500 rows x 4 columns]

# %% [markdown]
# ## 문제 5
# * KNN 이해하기

# %% [markdown]
# ### train과 test set 나누기

# %%
# train과 test set을 나누기 위한 함수
from sklearn.model_selection import train_test_split

# %%
# 아래 결과는 최초 data를 upload했을 때의 사이즈입니다.
data_final.shape
# Out:
# (10000, 4)

# %%
# 변수들과 label로 활용할 것을 나누는 작업
X = data_final.drop(['satisfaction'], axis=1)
y = data_final['satisfaction']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2) # test:train = 8:2

# %%
# 아래 결과는 train, test split의 사이즈입니다.
print("X_train's shape : ", X_train.shape)
print("X_test's shape : ", X_test.shape)
print("y_train's shape : ", y_train.shape)
print("y_test's shape : ", y_test.shape)
X_train.reset_index(drop=True, inplace=True)
X_test.reset_index(drop=True, inplace=True)
y_train.reset_index(drop=True, inplace=True)
y_test.reset_index(drop=True, inplace=True)
# Out:
# X_train's shape :  (8000, 3)
# X_test's shape :  (2000, 3)
# y_train's shape :  (8000,)
# y_test's shape :  (2000,)

# %% [markdown]
# ### 문제 5-1
# **`KNeighborsClassifier`**를 사용하여 test accuracy가 0.8 이상 나오도록 코드를 완성하고 코드를 보고서에 캡처하여 업로드하세요.
# * 조건: neightbor의 수 k=3으로  고정합니다.

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
################  문제 5-1  ####################
# 소스코드를 입력하고 캡처 후 보고서에 업로드하세요.
# 코드 시작과 코드 끝 라인을 삭제하지 마세요.
################ 코드 시작  #####################
KNNclassifier_name = KNeighborsClassifier(n_neighbors = 3)
KNNclassifier_name.fit(X_train,y_train)
################ 코드 끝  ######################
##############################################
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
test_acc = KNNclassifier_name.score(X_test, y_test)
print(test_acc)
# Out:
# 0.8325

# %% [markdown]
# ### 문제 5-2
# * Knn Classifier을 사용하여 K 값에 따라 변화하는 train accuracy, test accuracy를 그래프로 그리세요.
# * 소스코드와 그래프를 **함께** 보고서에 업로드하세요.

# %%
import matplotlib.pyplot as plt

# %%
K = [1, 3, 5, 15, 55, 101, 501]
train_acc = []
test_acc = []

for i in K:
################  문제 5-2  ####################
# 소스코드를 입력하고 캡처 후 보고서에 업로드하세요.
# 코드 시작과 코드 끝 라인을 삭제하지 마세요.
################ 코드 시작  #####################

# 소스코드를 입력하고 그래프와 함께 캡처 후 보고서에 업로드 하세요
  classifier = KNeighborsClassifier(n_neighbors = i)
  classifier.fit(X_train,y_train)
  train_acc.append(classifier.score(X_train,y_train))
  
  classifier.fit(X_test,y_test)
  test_acc.append(classifier.score(X_test,y_test))

################ 코드 끝  ######################
# x축을 K값, y축을 정확도로하여 K에 대한 train, test의 정확도에 대한 그래프 생성
plt.figure()
plt.plot(K, train_acc, label='train accuracy')
plt.plot(K, test_acc, label='test accuracy')
plt.xlabel('K')
plt.ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')

# %% [markdown]
# # 깃허브에 업로드하기
# * colab with github 문서 참고
