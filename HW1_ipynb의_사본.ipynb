# %% [markdown]
# <a href="https://colab.research.google.com/github/h-wi/2022F-Ajou-ML/blob/main/HW1_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HW1 :: Data preprocessing & KNN

# %% [markdown]
# ## 코랩과 구글 드라이브 연동하기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# pwd 명령어로 현재 위치 확인
# !pwd
# Out:
# 'pwd'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.

# %%
# !ls
# Out:
# 'ls'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.

# %%
# 이 노트북 파일이 저장되어 있는 디렉토리 위치까지 옮기기
cd drive
# Out:
#   Input In [2]
#     cd drive
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ---

# %% [markdown]
# ## 데이터 불러오기 & 살펴보기

# %%
# 이번 과제는 numpy, pandas와 같은 데이터를 불러내고 확인, 처리, 
# 수정 등을 쉽게 할 수 있는 library를 사용합니다.

# 모듈 이름 뒤에 as를 쓰고 별칭을 적으면 해당 별칭으로 모듈을 호출할 수 있습니다.
# 모듈명: numpy, 별칭: np => numpy를 쓰는 대신 np를 써서 numpy 호출
# 모듈명: pandas, 별칭: pd => pandas를 쓰는 대신 pd를 써서 pandas 호출
import numpy as np
import pandas as pd

# %%
# './'는 이 노트북 파일의 현재 위치를 뜻 합니다.
# 노트북 파일과 같은 위치에 데이터 파일을 두어야 아래와 같이 데이터 파일을 불러올 수 있습니다.
# kaggle 원본 데이터 파일과 다릅니다. 반드시 제공된 데이터를 사용하세요!
path = './airline_sampled.csv' 

# pandas의 read_csv 함수를 사용하여 csv파일을 DataFrame으로 불러옵니다.
data = pd.read_csv(path)

# %%
# DataFrame 혹은 Series와 같은 자료구조에 shape함수를 통해 데이터의 크기와 
# 변수의 갯수를 대략적으로 알 수 있습니다.

data.shape # (10000, 23) => 10000 개의 row(행), 23 개의 column(열)을 가진 데이터
# Out:
# (10000, 23)

# %%
# head() 함수를 이용하여 해당 데이터의 맨 위 5개의 원소를 볼 수 있습니다.
# 더 많은 행을 보고 싶다면 ()안에 숫자를 넣어주시면 됩니다.

data.head()
# Out:
#    Gender   Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0  Female  Loyal Customer   41  Personal Travel       Eco              569
# 1  Female  Loyal Customer   45  Personal Travel  Business             1085
# 2  Female  Loyal Customer   23  Personal Travel       Eco              468
# 3  Female  Loyal Customer   34  Personal Travel  Eco Plus              303
# 4    Male  Loyal Customer   21  Personal Travel       Eco             1190
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      2                                  5
# 1                      3                                  5
# 2                      3                                  2
# 3                      4                                  5
# 4                      4                                  4
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                       2              4  ...                       2
# 1                       2              3  ...                       4
# 2                       3              2  ...                       5
# 3                       4              2  ...                       3
# 4                       4              4  ...                       1
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 1                 5                 3                3
# 1                 4                 2                 4                4
# 2                 1                 4                 2                1
# 3                 5                 5                 5                3
# 4                 5                 3                 3                3
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 1            2                           0
# 1                 4            3                          23
# 2                 3            5                           4
# 3                 5            3                          49
# 4                 4            1                           8
#
#    Arrival Delay in Minutes             satisfaction
# 0                       0.0  neutral or dissatisfied
# 1                       0.0  neutral or dissatisfied
# 2                       0.0  neutral or dissatisfied
# 3                      50.0  neutral or dissatisfied
# 4                       0.0                satisfied
#
# [5 rows x 23 columns]

# %%
# tail() 함수를 이용하여 해당 데이터의 맨 뒤 5개의 원소를 볼 수 있습니다.
# 더 많은 행을 보고 싶다면 ()안에 숫자를 넣어주시면 됩니다.

data.tail()
# Out:
#      Gender   Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 9995   Male  Loyal Customer   53  Business travel       Eco              834
# 9996   Male  Loyal Customer   42  Business travel       Eco              134
# 9997   Male  Loyal Customer   64  Personal Travel  Eco Plus              425
# 9998   Male  Loyal Customer   46  Business travel  Business             2374
# 9999   Male  Loyal Customer   59  Business travel  Business             2637
#
#       Inflight wifi service  Departure/Arrival time convenient  \
# 9995                      1                                  4
# 9996                      2                                  2
# 9997                      2                                  2
# 9998                      3                                  3
# 9999                      4                                  4
#
#       Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 9995                       4              4  ...                       1
# 9996                       2              2  ...                       2
# 9997                       2              2  ...                       2
# 9998                       3              3  ...                       3
# 9999                       4              4  ...                       3
#
#       On-board service  Leg room service  Baggage handling  Checkin service  \
# 9995                 1                 1                 3                4
# 9996                 3                 4                 3                2
# 9997                 3                 2                 2                1
# 9998                 3                 4                 3                5
# 9999                 3                 4                 3                4
#
#       Inflight service  Cleanliness  Departure Delay in Minutes  \
# 9995                 4            1                          28
# 9996                 1            2                         143
# 9997                 3            2                           9
# 9998                 3            5                           0
# 9999                 3            4                          16
#
#       Arrival Delay in Minutes             satisfaction
# 9995                       8.0  neutral or dissatisfied
# 9996                     159.0  neutral or dissatisfied
# 9997                      84.0  neutral or dissatisfied
# 9998                       0.0                satisfied
# 9999                       1.0                satisfied
#
# [5 rows x 23 columns]

# %%
# DataFrame을 이루고 있는 column의 이름을 확인합니다.

data.columns
# Out:
# Index(['Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
# DataFrame을 이루고 있는 column 별 데이터의 타입을 확인합니다.

data.dtypes
# Out:
# Gender                                object
# Customer Type                         object
# Age                                    int64
# Type of Travel                        object
# Class                                 object
# Flight Distance                        int64
# Inflight wifi service                  int64
# Departure/Arrival time convenient      int64
# Ease of Online booking                 int64
# Gate location                          int64
# Food and drink                         int64
# Online boarding                        int64
# Seat comfort                           int64
# Inflight entertainment                 int64
# On-board service                       int64
# Leg room service                       int64
# Baggage handling                       int64
# Checkin service                        int64
# Inflight service                       int64
# Cleanliness                            int64
# Departure Delay in Minutes             int64
# Arrival Delay in Minutes             float64
# satisfaction                          object
# dtype: object

# %%
# describe()는 각 column에 대해 통계량을 요약해주는 함수입니다.
# 기본적으로 NaN(누락데이터)는 제외하고 데이터 요약이 수행됩니다.

data.describe()
# Out:
#                 Age  Flight Distance  Inflight wifi service  \
# count  10000.000000     10000.000000           10000.000000
# mean      39.528600      1199.730400               2.747700
# std       15.091122      1014.036332               1.320234
# min        7.000000        31.000000               0.000000
# 25%       27.000000       407.000000               2.000000
# 50%       40.000000       842.000000               3.000000
# 75%       51.000000      1749.000000               4.000000
# max       85.000000      4983.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                       10000.000000            10000.000000
# mean                            3.062200                2.767800
# std                             1.511277                1.398027
# min                             0.000000                0.000000
# 25%                             2.000000                2.000000
# 50%                             3.000000                3.000000
# 75%                             4.000000                4.000000
# max                             5.000000                5.000000
#
#        Gate location  Food and drink  Online boarding  Seat comfort  \
# count   10000.000000    10000.000000     10000.000000  10000.000000
# mean        2.984700        3.213200         3.266700      3.440600
# std         1.278683        1.316176         1.342293      1.308833
# min         0.000000        0.000000         0.000000      1.000000
# 25%         2.000000        2.000000         2.000000      2.000000
# 50%         3.000000        3.000000         4.000000      4.000000
# 75%         4.000000        4.000000         4.000000      5.000000
# max         5.000000        5.000000         5.000000      5.000000
#
#        Inflight entertainment  On-board service  Leg room service  \
# count            10000.000000      10000.000000      10000.000000
# mean                 3.360000          3.380600          3.363200
# std                  1.332208          1.293024          1.318507
# min                  1.000000          1.000000          0.000000
# 25%                  2.000000          2.000000          2.000000
# 50%                  4.000000          4.000000          4.000000
# 75%                  4.000000          4.000000          4.000000
# max                  5.000000          5.000000          5.000000
#
#        Baggage handling  Checkin service  Inflight service   Cleanliness  \
# count      10000.000000     10000.000000      10000.000000  10000.000000
# mean           3.634600         3.296500          3.633600      3.286000
# std            1.190388         1.259661          1.185028      1.297294
# min            1.000000         1.000000          1.000000      1.000000
# 25%            3.000000         2.000000          3.000000      2.000000
# 50%            4.000000         3.000000          4.000000      3.000000
# 75%            5.000000         4.000000          5.000000      4.000000
# max            5.000000         5.000000          5.000000      5.000000
#
#        Departure Delay in Minutes  Arrival Delay in Minutes
# count                10000.000000               9965.000000
# mean                    14.610200                 15.148319
# std                     36.684733                 37.203171
# min                      0.000000                  0.000000
# 25%                      0.000000                  0.000000
# 50%                      0.000000                  0.000000
# 75%                     13.000000                 14.000000
# max                    748.000000                720.000000

# %% [markdown]
# ## 문제 1 :: 변수의 타입

# %% [markdown]
# * 보고서에 설명된 것을 바탕을 주어진 데이터의 변수들의 타입을 보고서에 기술하세요.
#
#   * 작성 형식) : 1. 변수 이름: categorical
#   * 작성 예시) 1. Age: Numeric

# %% [markdown]
# 정답)
# * Gender: categorical
# * Customer type: categorical
# * Age: Numeric
# * Type of travel: categorical
# * Class: categorical
# * Flight Distance: Numeric
# * Inflight wifi service: Numeric
# * Departure/Arrival time convenient: Numeric
# * Ease of Online booking: Numeric
# * Gate location: Numeric
# * Food and drink: Numeric
# * Online boarding: Numeric
# * Seat comfort: Numeric
# * Inflight entertainment: Numeric
# * On-board service: Numeric
# * Leg room service: Numeric
# * Baggage handling: Numeric
# * Checkin service: Numeric
# * Inflight service: Numeric
# * Cleanliness: Numeric
# * Departure Delay in Minutes: Numeric
# * Arrival Delay in Minutes: Numeric
# * satisfaction: categorical

# %% [markdown]
# ## 결측값과 중복값 확인하기
# 결측값과 중복값은 데이터 분석 결과에 큰 영향을 줍니다.
# 제공된 데이터에 결측값과 중복값이 있는지 알아봅시다.

# %%
# isnull()는 DataFrame에 있는 결측치(NA)를 boolean 값으로 반환하는 함수입니다.
# 결측치가 있으면 True를 반환합니다.

data.isnull().head()
# Out:
#    Gender  Customer Type    Age  Type of Travel  Class  Flight Distance  \
# 0   False          False  False           False  False            False
# 1   False          False  False           False  False            False
# 2   False          False  False           False  False            False
# 3   False          False  False           False  False            False
# 4   False          False  False           False  False            False
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                  False                              False
# 1                  False                              False
# 2                  False                              False
# 3                  False                              False
# 4                  False                              False
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                   False          False  ...                   False
# 1                   False          False  ...                   False
# 2                   False          False  ...                   False
# 3                   False          False  ...                   False
# 4                   False          False  ...                   False
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0             False             False             False            False
# 1             False             False             False            False
# 2             False             False             False            False
# 3             False             False             False            False
# 4             False             False             False            False
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0             False        False                       False
# 1             False        False                       False
# 2             False        False                       False
# 3             False        False                       False
# 4             False        False                       False
#
#    Arrival Delay in Minutes  satisfaction
# 0                     False         False
# 1                     False         False
# 2                     False         False
# 3                     False         False
# 4                     False         False
#
# [5 rows x 23 columns]

# %%
# isnull()에 sum() 를 결합하여 DataFrame에 있는 결측치의 합을 구합니다.

data.isnull().sum() # 문제3에서 KNN Imputer를 사용하여 결측값을 보정할 예정
# Out:
# Gender                                0
# Customer Type                         0
# Age                                   0
# Type of Travel                        0
# Class                                 0
# Flight Distance                       0
# Inflight wifi service                 0
# Departure/Arrival time convenient     0
# Ease of Online booking                0
# Gate location                         0
# Food and drink                        0
# Online boarding                       0
# Seat comfort                          0
# Inflight entertainment                0
# On-board service                      0
# Leg room service                      0
# Baggage handling                      0
# Checkin service                       0
# Inflight service                      0
# Cleanliness                           0
# Departure Delay in Minutes            0
# Arrival Delay in Minutes             35
# satisfaction                          0
# dtype: int64

# %%
# duplicated()는 중복된 데이터를 Series 형식으로 반환합니다.

data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
# duplicated()에 sum()을 결합하여 DataFrame에 있는 중복 데이터의 합을 구합니다.

data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 문제 2 :: 데이터 정리

# %% [markdown]
# ### 문제 2-1
# 제공된 데이터에서 categorical 변수들을 주어진 조건에 따라 인코딩하고 작성한 코드를 캡처 후 보고서에 업로드 하세요.
#
# * data에서 satisfaction 열의 데이터 값을 `neutral or dissatisfied` 일 경우 0, `satisfied`일 경우 1로 인코딩하세요.
#
# * data에서 Gender 열의 데이터 값을 `Male`일 경우 0, `Female`일 경우 1로 인코딩하세요.
#
# * data에서 Customer Type 열의 데이터 값을 `disloyal Customer`일 경우 0, `Loyal Customer`일 경우 1로 인코딩하세요.
#
# * data에서 Class 열의 데이터 값을 `Eco`일 경우 0, `Eco Plus`일 경우 1, `Business`일 경우 2로 인코딩하세요.
#
# * data에서 'Type of Travel 열의 데이터 값을 `Personal Travel`일 경우 0, `Business travel`일 경우 1로 인코딩하세요.

# %%
data['Type of Travel'].unique()
# Out:
# array([0, 1])

# %%
data['Customer Type'].unique()
# Out:
# array([1, 0])

# %%
data['satisfaction'].unique() # satisfaction 열은 두 가지의 클래스로 구성되어 있다는 것을 확인합니다.
# Out:
# array([0, 1])

# %%
data['Class'].unique()
# Out:
# array([0, 2, 1])

# %%
################  문제 2-1  ####################
# 소스코드를 입력하고 캡처 후 보고서에 업로드하세요.
# 코드 시작과 코드 끝 라인을 삭제하지 마세요.
################ 코드 시작  #####################

satisfaction_map = {'neutral or dissatisfied' : 0, 'satisfied' : 1}
Gender_map = {'Male': 0 , 'Female':1}
Customer_Type_map = {'disloyal Customer':0, 'Loyal Customer':1}   #조건에 맞게 각 열의 이름을 mapping
Class_map ={'Eco' :0, 'Eco Plus':1,'Business':2}
Type_of_Travel_map = {'Personal Travel':0, 'Business travel':1}

data['satisfaction'] = data['satisfaction'].map(satisfaction_map)
data['Gender'] = data['Gender'].map(Gender_map)                            # data에 적용하여 label encoding
data['Customer Type'] = data['Customer Type'].map(Customer_Type_map)
data['Class'] = data['Class'].map(Class_map)
data['Type of Travel'] = data['Type of Travel'].map(Type_of_Travel_map)

##################################################

# %%
data.shape
# Out:
# (10000, 23)

# %%
# 인코딩한 데이터 열의 데이터 속성을 변환하는 코드
data['satisfaction'] = data['satisfaction'].astype('int')
data['Gender'] = data['Gender'].astype('int')
data['Customer Type'] = data['Customer Type'].astype('int')
data['Class'] = data['Class'].astype('int')
data['Type of Travel'] = data['Type of Travel'].astype('int')

# %% [markdown]
# ### 문제 2-2
# `Arrival Delay in Minutes` 열은 현재 분 단위로 데이터가 구성되어 있습니다.
# 시간 단위로 데이터를 나타내는 `delay_in_hours`을 작성하고 캡처하여 보고서에 업로드 하세요.
#
#
# 예) 18분 => 18/60=0.3

# %%
################  문제 2-2  ####################
# 소스코드를 입력하고 캡처 후 보고서에 업로드하세요.
# 코드 시작과 코드 끝 라인을 삭제하지 마세요.
################ 코드 시작  #####################
def delay_in_hours(row):
  return row/60
################ 코드 끝 ########################
#################################################

# %%
data['Arrival Delay in Minutes'] = data['Arrival Delay in Minutes'].apply(lambda row: delay_in_hours(row))

# %%
data # Arrival Delay in Minutes 열이 바뀌었는지 확인
# Out:
#       Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0          1              1   41               0      0              569
# 1          1              1   45               0      2             1085
# 2          1              1   23               0      0              468
# 3          1              1   34               0      1              303
# 4          0              1   21               0      0             1190
# ...      ...            ...  ...             ...    ...              ...
# 9995       0              1   53               1      0              834
# 9996       0              1   42               1      0              134
# 9997       0              1   64               0      1              425
# 9998       0              1   46               1      2             2374
# 9999       0              1   59               1      2             2637
#
#       Inflight wifi service  Departure/Arrival time convenient  \
# 0                         2                                  5
# 1                         3                                  5
# 2                         3                                  2
# 3                         4                                  5
# 4                         4                                  4
# ...                     ...                                ...
# 9995                      1                                  4
# 9996                      2                                  2
# 9997                      2                                  2
# 9998                      3                                  3
# 9999                      4                                  4
#
#       Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                          2              4  ...                       2
# 1                          2              3  ...                       4
# 2                          3              2  ...                       5
# 3                          4              2  ...                       3
# 4                          4              4  ...                       1
# ...                      ...            ...  ...                     ...
# 9995                       4              4  ...                       1
# 9996                       2              2  ...                       2
# 9997                       2              2  ...                       2
# 9998                       3              3  ...                       3
# 9999                       4              4  ...                       3
#
#       On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                    1                 5                 3                3
# 1                    4                 2                 4                4
# 2                    1                 4                 2                1
# 3                    5                 5                 5                3
# 4                    5                 3                 3                3
# ...                ...               ...               ...              ...
# 9995                 1                 1                 3                4
# 9996                 3                 4                 3                2
# 9997                 3                 2                 2                1
# 9998                 3                 4                 3                5
# 9999                 3                 4                 3                4
#
#       Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                    1            2                    0.000000
# 1                    4            3                    0.383333
# 2                    3            5                    0.066667
# 3                    5            3                    0.816667
# 4                    4            1                    0.133333
# ...                ...          ...                         ...
# 9995                 4            1                    0.466667
# 9996                 1            2                    2.383333
# 9997                 3            2                    0.150000
# 9998                 3            5                    0.000000
# 9999                 3            4                    0.266667
#
#       Arrival Delay in Minutes  satisfaction
# 0                     0.000000             0
# 1                     0.000000             0
# 2                     0.000000             0
# 3                     0.833333             0
# 4                     0.000000             1
# ...                        ...           ...
# 9995                  0.133333             0
# 9996                  2.650000             0
# 9997                  1.400000             0
# 9998                  0.000000             1
# 9999                  0.016667             1
#
# [10000 rows x 23 columns]

# %%
data['Departure Delay in Minutes'] = data['Departure Delay in Minutes'].apply(lambda row: delay_in_hours(row))

# %% [markdown]
# ### 문제 2-3
# `Departure Delay in Minutes`와 `Arrival Delay in Minutes` 열의 이름을 각각 `Departure Delay in Hours`와 `Arrival Delay in Hours`로 변경하세요.
#
# **코드를 보고서에 캡처하여 업로드하세요.**

# %%
################  문제 2-3  #################
# 열 이름 변경하기
# 소스코드를 입력하고 캡처 후 보고서에 업로드하세요.
# 코드 시작과 코드 끝 라인을 삭제하지 마세요.
################ 코드 시작  ##################
data.rename(columns={'Departure Delay in Minutes' : 'Departure Delay in Hours'}, inplace = True)
data.rename(columns={'Arrival Delay in Minutes' : 'Arrival Delay in Hours'}, inplace = True)
################ 코드 끝  ####################
##############################################

# %% [markdown]
# ## 문제 3 :: KNN Imputer

# %% [markdown]
# ### **`Arrival Delay in Hours`** 열과 연관성이 높은 열 찾기

# %% [markdown]
# 결측값이 있는 모든 행과 결측값이 없는 데이터 사이의 거리를 구할 수 있지만, 계산 시간이 매우 오려 걸려 `Arrival Delay in Hours` 열과 가장 연관성이 높은 `Departure Delay in Hours` 과의 거리를 기준으로 결측값을 보정합니다.

# %%
corr = data.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_f0aba_row0_col0, #T_f0aba_row1_col1, #T_f0aba_row2_col2, #T_f0aba_row3_col3, #T_f0aba_row4_col4, #T_f0aba_row5_col5, #T_f0aba_row6_col6, #T_f0aba_row7_col7, #T_f0aba_row8_col8, #T_f0aba_row9_col9, #T_f0aba_row10_col10, #T_f0aba_row11_col11, #T_f0aba_row12_col12, #T_f0aba_row13_col13, #T_f0aba_row14_col14, #T_f0aba_row15_col15, #T_f0aba_row16_col16, #T_f0aba_row17_col17, #T_f0aba_row18_col18, #T_f0aba_row19_col19, #T_f0aba_row20_col20, #T_f0aba_row21_col21, #T_f0aba_row22_col22 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T
{
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_f0aba_row1_col22, #T_f0aba_row11_col17, #T_f0aba_row12_col2, #T_f0aba_row13_col6, #T_f0aba_row18_col4, #T_f0aba_row22_col10 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_f0aba_row2_col1, #T_f0aba_row7_col8 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_f0aba_row2_col3, #T_f0aba_row10_col1, #T_f0aba_row14_col1, #T_f0aba_row14_col17, #T_f0aba_row15_col4, #T_f0aba_row17_col7 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_f0aba_row2_col4, #T_f0aba_row8_col22, #T_f0aba_row12_col17, #T_f0aba_row17_col11, #T_f0aba_row19_col7 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_f0aba_row2_col5, #T_f0aba_row3_col6, #T_f0aba_row7_col18, #T_f0aba_row12_col6, #T_f0aba_row12_col15, #T_f0aba_row16_col19, #T_f0aba_row18_col6, #T_f0aba_row19_col2 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_f0aba_row2_col6, #T_f0aba_row7_col0, #T_f0aba_row7_col13, #T_f0aba_row9_col11, #T_f0aba_row9_col15, #T_f0aba_row11_col21, #T_f0aba_row13_col0, #T_f0aba_row13_col21, #T_f0aba_row14_col0, #T_f0aba_row14_col20, #T_f0aba_row17_col0, #T_f0aba_row21_col5 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_f0aba_row2_col7, #T_f0aba_row4_col13 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_f0aba_row2_col11, #T_f0a

# %% [markdown]
# `Departure Delay in Hours` 와 `Arrival Delay in Hours`의 상관 계수가 0.96인 것으로 보아 두 열이 큰 상관 관계를 가짐을 알 수 있습니다.   따라서 두 열만 골라 X라는 데이터프레임을 만듭니다.

# %%
X = data[['Departure Delay in Hours', 'Arrival Delay in Hours']]

# %% [markdown]
# ### 문제 3-1, 3-2
# K-Nearest Neighbor Imputation(강의노트 24쪽)을 이용하여 결측치 채우기

# %% [markdown]
# ### 문제 3-1
# 주어진 코드틀에 데이터프레임 X와 결측값이 있는 행 데이터 간의 거리 구하는 코드를 작성하세요.
# * 주의) 코드틀 이외의 부분에 코드를 작성하지 마세요!
# * 주의) 소스코드를 입력하고 캡처 후 보고서에 업로드하세요.
# * 주의) 코드 시작과 코드 끝 라인을 삭제하지 마세요.

# %% [markdown]
# ### 문제 3-2
# 주어진 코드틀에 k개의 "Arrival Delay in Hours" 값을 보고 평균을 내어 결측값을 결정하는 코드를 작성하세요.
# * 주의) 코드틀 이외의 부분에 코드를 작성하지 마세요!
# * 주의) 소스코드를 입력하고 캡처 후 보고서에 업로드하세요.
# * 주의) 코드 시작과 코드 끝 라인을 삭제하지 마세요.

# %%
import tqdm

# %%
class Knn_imputer():
  def __init__(self, n_neighbors): 
        
    ## 생성자로 최근접 이웃수(n_neighbors)를 입력 받습니다.
    self.k = n_neighbors    
  
  ## knn 은 lazy learning 입니다.
  def fit(self,X):
      self.X = X
  
  def predict(self, X):

    for i in tqdm.tqdm(range(len(X))):
     if pd.isnull(X['Arrival Delay in Hours'].iloc[i]): # Arrival Delay 열에 있는 결측값 확인

        distance = self.dist(X, X.iloc[i]) # 데이터프레임 X와 결측값이 있는 행 데이터 간의 거리 구하는 함수
      
        
        sorted_dist = sorted(distance.items(), key=lambda x: x[1]) # distance 를 sorting 하기
         ################  문제 3-2  ####################
         # k개의 "Arrival Delay in Hours" 값을 보고 평균 내어
         # 값을 결정하기
         
         # 소스코드를 입력하고 캡처 후 보고서에 업로드하세요.
         # 코드 시작과 코드 끝 라인을 삭제하지 마세요.
        ################ 코드 시작  #####################
           #264 0.65        #692 0.07222
        val = 0
        j = 0
        count = 0
        while True:
            if (count == self.k): 
                break; 
            if(pd.isnull(X['Arrival Delay in Hours'].iloc[sorted_dist[j][0]])): #sorted_dist를 인덱싱으로 활용-> 
                j = j + 1                                                       # 결측값을 가르키는부분이라면
                continue                                                       # continue -> if(is_null) then i+=1
            else:
                val = val + X['Arrival Delay in Hours'].iloc[sorted_dist[j][0]] #아니면 val에 더하기
                count = count + 1
            j = j + 1
        X['Arrival Delay in Hours'].iloc[i] = val / self.k #k값으로 나눈 값을 결측값이 있는 행에 저장
        ################ 코드 끝  ######################
        ##############################################
        
  
  def dist(self, X, y):
    num_train = X.shape[0]

    X = X.drop(['Arrival Delay in Hours'], axis=1)
    y = y.drop(['Arrival Delay in Hours'])
    dist_dict = {} ## {index : distance} 형태
    
    for i in range(num_train):
    
    ################  문제 3-1  ####################
    # 데이터프레임 X와 결측값이 있는 행 데이터 간의 거리 구하기
    # 소스코드를 입력하고 캡처 후 보고서에 업로드하세요.
    # 코드 시작과 코드 끝 라인을 삭제하지 마세요.
    ################ 코드 시작  #####################
        dist = y - X.iloc[i] # 결측값이 있는 행의 departure값과 나머지 행의 값과의 거리
        dist_dict[i] = abs(dist.values) # 정렬하기 위해 abs값을 씌움
    ################ 코드 끝  ######################
    ##############################################

    return dist_dict

# %%
imputer = Knn_imputer(3)
imputer.fit(X)

# test set에 대해 predict를 진행합니다.
imputer.predict(X) # 오래 걸립니다
# Out:
#   0%|                                                                                        | 0/10000 [00:00<?, ?it/s]C:\Users\bnmbn\AppData\Local\Temp\ipykernel_23356\2816743285.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Arrival Delay in Hours'].iloc[i] = val / self.k
#   3%|██                                                                            | 265/10000 [00:04<02:27, 66.10it/s]C:\Users\bnmbn\AppData\Local\Temp\ipykernel_23356\2816743285.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Arrival Delay in Hours'].iloc[i] = val / self.k
#   7%|█████▎                                                                       | 693/10000 [00:06<01:27, 106.79it/s]C:\Users\bnmbn\AppData\Local\Temp\ipykernel_23356\2816743285.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Arrival Delay in Hours'].iloc[i] = val / self.k
#   7%|█████▋                                                                        | 734/10000 [00:10<02:36, 59.15it/s]C:\Users\bnmbn\AppData\Local\Temp\ipykernel_23356\2816743285.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Arrival Delay in Hours'].iloc[i] = val / self.k
#   8%|█████▉                                                                        | 754/10000 [00:14<03:54, 39.40it/s]C:\Users\bnmbn\AppData\Local\Temp\ipykernel_23356\2816743285.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Arrival Delay in Hours'].iloc[i] = val / self.k
#   8%|██████▏                                                                       | 791/10000 [00:17<05:02, 30.44it/s]C:\Users\bnmbn\AppData\Local\Temp\ipykernel_23356\2816743285.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Arrival Delay in Hours'].iloc[i] = val / self.k
#   9%|██████▉                                                                       | 887/10000 [00:20<05:01, 30.24it/s]C:\Users\bnmbn\AppData\Local\Temp\ipykernel_23356\2816743285.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Arrival Delay in Hours'].iloc[i] = val / self.k
#  14%|██████████▌                                                                  | 1366/10000 [00:23<02:03, 70.12it/s]C:\Users\bnmbn\AppData\Local\Temp\ipykernel_23356\2816743285.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Arrival Delay in Hours'].iloc[i] = val / self.k
#  16%|████████████▌                                                                | 1630/10000 [00:27<01:57, 71.25it/s]C:\Users\bnmbn\AppData\Local\Temp\ipykernel_23356\2816743285.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Arrival Delay in Hours'].iloc[i] = val / self.k
#  23%|█████████████████▏                                                          | 2266/10000 [00:29<01:07, 114.50it/s]C:\Users\bnmbn\AppData\Local\Temp\ipykernel_23356\2816743285.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Arrival Delay in Hours'].iloc[i] = val / self.k
#  24%|██████████████████▍                                                          | 2400/10000 [00:32<01:19, 95.99it/s]C:\Users\bnmbn\AppData\Local\Temp\ipykernel_23356\2816743285.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Arrival Delay in Hours'].iloc[i] = val / self.k
#  25%|███████████████████                                                          | 2475/10000 [00:35<01:37, 77.38it/s]C:\Users\bnmbn\AppData\Local\Temp\ipykernel_23356\2816743285.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Arrival Delay in Hours'].iloc[i] = val / self.k
#  31%|███████████████████████▋                                                    | 3115/10000 [00:37<00:52, 131.88it/s]C:\Users\bnmbn\AppData\Local\Temp\ipykernel_23356\2816743285.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Arrival Delay in Hours'].iloc[i] = val / self.k
#  33%|████████████████████████▊                                                   | 3269/10000 [00:38<00:53, 125.13it/s]C:\Users\bnmbn\AppData\Local\Temp\ipykernel_23356\2816743285.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Arrival Delay in Hours'].iloc[i] = val / self.k
#  38%|████████████████████████████▌                                               | 3766/10000 [00:40<00:37, 166.42it/s]C:\Users\bnmbn\AppData\Local\Temp\ipykernel_23356\2816743285.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Arrival Delay in Hours'].iloc[i] = val / self.k
#  39%|█████████████████████████████▎                                              | 3857/10000 [00:42<00:44, 139.00it/s]C:\Users\bnmbn\AppData\Local\Temp\ipykernel_23356\2816743285.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Arrival Delay in Hours'].iloc[i] = val / self.k
#  40%|██████████████████████████████▍                                             | 3997/10000 [00:43<00:47, 126.71it/s]C:\Users\bnmbn\AppData\Local\Temp\ipykernel_23356\2816743285.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Arrival Delay in Hours'].iloc[i] = val / self.k
#  40%|██████████████████████████████▉                                              | 4015/10000 [00:45<01:02, 96.00it/s]C:\Users\bnmbn\AppData\Local\Temp\ipykernel_23356\2816743285.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Arrival Delay in Hours'].iloc[i] = val / self.k
#  44%|█████████████████████████████████▍                                          | 4399/10000 [00:46<00:40, 136.91it/s]C:\Users\bnmbn\AppData\Local\Temp\ipykernel_23356\2816743285.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Arrival Delay in Hours'].iloc[i] = val / self.k
#  48%|████████████████████████████████████▍                                       | 4789/10000 [00:48<00:30, 169.96it/s]C:\Users\bnmbn\AppData\Local\Temp\ipykernel_23356\2816743285.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Arrival Delay in Hours'].iloc[i] = val / self.k
#  51%|███████████████████████████████████████                                     | 5143/10000 [00:49<00:26, 186.69it/s]C:\Users\bnmbn\AppData\Local\Temp\ipykernel_23356\2816743285.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Arrival Delay in Hours'].iloc[i] = val / self.k
#  63%|███████████████████████████████████████████████▌                            | 6252/10000 [00:51<00:11, 338.12it/s]C:\Users\bnmbn\AppData\Local\Temp\ipykernel_23356\2816743285.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['
# 264                5               1      1             1
#
# [265 rows x 4 columns]

# %% [markdown]
# ## 문제 5
# * KNN 이해하기

# %% [markdown]
# ### train과 test set 나누기

# %%
# train과 test set을 나누기 위한 함수
from sklearn.model_selection import train_test_split

# %%
# 아래 결과는 최초 data를 upload했을 때의 사이즈입니다.
data_final.shape
# Out:
# (10000, 4)

# %%
# 변수들과 label로 활용할 것을 나누는 작업
X = data_final.drop(['satisfaction'], axis=1)
y = data_final['satisfaction']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2) # test:train = 8:2

# %%
# 아래 결과는 train, test split의 사이즈입니다.
print("X_train's shape : ", X_train.shape)
print("X_test's shape : ", X_test.shape)
print("y_train's shape : ", y_train.shape)
print("y_test's shape : ", y_test.shape)
X_train.reset_index(drop=True, inplace=True)
X_test.reset_index(drop=True, inplace=True)
y_train.reset_index(drop=True, inplace=True)
y_test.reset_index(drop=True, inplace=True)
# Out:
# X_train's shape :  (8000, 3)
# X_test's shape :  (2000, 3)
# y_train's shape :  (8000,)
# y_test's shape :  (2000,)

# %% [markdown]
# ### 문제 5-1
# **`KNeighborsClassifier`**를 사용하여 test accuracy가 0.8 이상 나오도록 코드를 완성하고 코드를 보고서에 캡처하여 업로드하세요.
# * 조건: neightbor의 수 k=3으로  고정합니다.

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
################  문제 5-1  ####################
# 소스코드를 입력하고 캡처 후 보고서에 업로드하세요.
# 코드 시작과 코드 끝 라인을 삭제하지 마세요.
################ 코드 시작  #####################
from sklearn.preprocessing import minmax_scale
X_train_std = pd.DataFrame(minmax_scale(X_train))
X_test_std =  pd.DataFrame(minmax_scale(X_test))
X_train = X_train_std
X_test = X_test_std

KNNclassifier_name = KNeighborsClassifier(n_neighbors = 3)
KNNclassifier_name.fit(X_train,y_train)
################ 코드 끝  ######################
##############################################
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
test_acc = KNNclassifier_name.score(X_test, y_test)
print(test_acc)
# Out:
# 0.8415

# %% [markdown]
# ### 문제 5-2
# * Knn Classifier을 사용하여 K 값에 따라 변화하는 train accuracy, test accuracy를 그래프로 그리세요.
# * 소스코드와 그래프를 **함께** 보고서에 업로드하세요.

# %%
import matplotlib.pyplot as plt

# %%
K = [1, 3, 5, 15, 55, 101, 501]
train_acc = []
test_acc = []

for i in K:
################  문제 5-2  ####################
# 소스코드를 입력하고 캡처 후 보고서에 업로드하세요.
# 코드 시작과 코드 끝 라인을 삭제하지 마세요.
################ 코드 시작  #####################

# 소스코드를 입력하고 그래프와 함께 캡처 후 보고서에 업로드 하세요

#정규화 min_max, z-score...
  classifier = KNeighborsClassifier(n_neighbors = i)
  classifier.fit(X_train,y_train)
  train_acc.append(classifier.score(X_train,y_train))
  test_acc.append(classifier.score(X_test,y_test))

################ 코드 끝  ######################
# x축을 K값, y축을 정확도로하여 K에 대한 train, test의 정확도에 대한 그래프 생성
plt.figure()
plt.plot(K, train_acc, label='train accuracy')
plt.plot(K, test_acc, label='test accuracy')
plt.xlabel('K')
plt.ylabel('accuracy') #주황색이 파랑색보다 위에 (주황색이 test, 파란색이 train)
# Out:
# Text(0, 0.5, 'accuracy')

# %% [markdown]
# # 깃허브에 업로드하기
# * colab with github 문서 참고
